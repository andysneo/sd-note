# %% [markdown]
# # **All In One SD Webui**
# A Colab Notebook For Stable Diffusion Webui
#
# [Github](https://github.com/andysneo/sd-note/blob/main/all_in_1_lite_webui_colab.ipynb) | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/andysneo/sd-note/blob/main/all_in_1_lite_webui_colab.ipynb)

# %%
#@title 1. Install Dependencies

#@markdown #Mount Google Drive
from google.colab import drive

mount_drive = False  # @param {type: "boolean"}
if mount_drive:
  if not os.path.exists("/content/drive"):
    drive.mount('/content/drive')
#@markdown ___

#@markdown #Extensions
import os
from google.colab.output import eval_js
os.environ['colab_url'] = eval_js("google.colab.kernel.proxyPort(7860, {'cache': false})")

# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt install -qq libunwind8-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb

# !pip install torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 --extra-index-url https://download.pytorch.org/whl/cu116 -U
# !apt -y install -qq aria2
# !pip install -q --pre xformers==0.0.17.dev476 -U
# !pip install -q --pre triton

Controlnet = True #@param {type:"boolean"}
Images_Browser = False #@param {type:"boolean"}
Huggingface = False #@param {type:"boolean"}
Civitai_Browser = False #@param {type:"boolean"}
Additional_Networks = False #@param {type:"boolean"}
Openpose_Editor = False #@param {type:"boolean"}
Depth_Lib = False #@param {type:"boolean"}
Posex = False #@param {type:"boolean"}
Tunnels = False #@param {type:"boolean"}
Batchlinks = False #@param {type:"boolean"}

# !git clone -b v2.0 https://github.com/camenduru/stable-diffusion-webui
# !wget https://raw.githubusercontent.com/camenduru/stable-diffusion-webui-scripts/main/run_n_times.py -O /content/stable-diffusion-webui/scripts/run_n_times.py
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-webui /content/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui

if Controlnet:
  # !git clone https://github.com/Mikubill/sd-webui-controlnet /content/stable-diffusion-webui/extensions/sd-webui-controlnet
if Images_Browser:
  # !git clone https://github.com/AlUlkesh/stable-diffusion-webui-images-browser /content/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser
if Huggingface:
  # !git clone https://github.com/camenduru/stable-diffusion-webui-huggingface /content/stable-diffusion-webui/extensions/stable-diffusion-webui-huggingface
if Civitai_Browser:
  # !git clone -b v2.0 https://github.com/camenduru/sd-civitai-browser /content/stable-diffusion-webui/extensions/sd-civitai-browser
if Additional_Networks:
  # !git clone https://github.com/kohya-ss/sd-webui-additional-networks /content/stable-diffusion-webui/extensions/sd-webui-additional-networks
if Openpose_Editor:
  # !git clone https://github.com/camenduru/openpose-editor /content/stable-diffusion-webui/extensions/openpose-editor
if Depth_Lib:
  # !git clone https://github.com/jexom/sd-webui-depth-lib /content/stable-diffusion-webui/extensions/sd-webui-depth-lib
if Posex:
  # !git clone https://github.com/hnmr293/posex /content/stable-diffusion-webui/extensions/posex
if Tunnels:
  # !git clone https://github.com/camenduru/sd-webui-tunnels /content/stable-diffusion-webui/extensions/sd-webui-tunnels
if Batchlinks:
  # !git clone https://github.com/etherealxx/batchlinks-webui /content/stable-diffusion-webui/extensions/batchlinks-webui
# %cd /content/stable-diffusion-webui
# !git reset --hard


if Controlnet:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_canny-fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_canny-fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_depth-fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_depth-fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_hed-fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_hed-fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_mlsd-fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_mlsd-fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_normal-fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_normal-fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_openpose-fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_openpose-fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_scribble-fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_scribble-fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_seg-fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_seg-fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/hand_pose_model.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/openpose -o hand_pose_model.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/body_pose_model.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/openpose -o body_pose_model.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/dpt_hybrid-midas-501f0c75.pt -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/midas -o dpt_hybrid-midas-501f0c75.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_large_512_fp32.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd -o mlsd_large_512_fp32.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_tiny_512_fp32.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd -o mlsd_tiny_512_fp32.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/network-bsds500.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/hed -o network-bsds500.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/upernet_global_small.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer -o upernet_global_small.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_style_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_style_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_sketch_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_sketch_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_seg_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_seg_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_openpose_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_openpose_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_keypose_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_keypose_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_depth_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_depth_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_color_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_color_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_canny_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_canny_sd14v1.pth

# %%
#@title 2. Download Models
#@markdown #Basic Models

# https://raw.githubusercontent.com/db0/AI-Horde-image-model-reference/main/db.json
StableDiffusion_v1_5 = True #@param {type:"boolean"}
Deliberate_v2 = True #@param {type:"boolean"}
Dreamlike_Diffusion_v1 = False #@param {type:"boolean"}
Chilloutmix_NiPrunedFp16 = True #@param {type:"boolean"}
Chilled_re_generic = False #@param {type:"boolean"}
Anything_Diffusion = False #@param {type:"boolean"}
RealismEngine = False #@param {type:"boolean"}
Lawlas_YiffMix_inclVae = False #@param {type:"boolean"}
Mdjrny_v4 = False #@param {type:"boolean"}
#XXXXXXX = False #@param {type:"boolean"}

if StableDiffusion_v1_5:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/sd15/resolve/main/v1-5-pruned-emaonly.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o v1-5-pruned-emaonly.ckpt
if Chilloutmix_NiPrunedFp16:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/residentchiefnz/HordeVAEMergeModelsTest/resolve/main/chilloutmix_NiPrunedFp16.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o chilloutmix_NiPrunedFp16.ckpt
if Deliberate_v2:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/XpucT/Deliberate/resolve/main/deliberate_v2.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o deliberate_v2.ckpt
if Dreamlike_Diffusion_v1:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/dreamlike-diffusion-1.0/resolve/main/dreamlike-diffusion-1.0.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o dreamlike-diffusion-1.0.ckpt
if Dreamlike_Diffusion_v1:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Airic/mirrors/resolve/main/Anything-Diffusion.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o Anything-Diffusion.ckpt
if RealismEngine:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/residentchiefnz/HordeVAEMergeModelsTest/resolve/main/RealismEngine_incl84000.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o RealismEngine_incl84000.ckpt
if Lawlas_YiffMix_inclVae:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Airic/lawlas-yiff-mix/resolve/main/Lawlas-YiffMix-inclVae.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o Lawlas-YiffMix-inclVae.ckpt
if Mdjrny_v4:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/prompthero/openjourney/resolve/main/mdjrny-v4.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o mdjrny-v4.ckpt
if Chilled_re_generic:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/nolanaatama/chlldrgnrc/resolve/main/chilled_re-generic.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o chilled_re-generic.safetensors
#@markdown ___
#@markdown #Optional Models

F222 = False #@param {type:"boolean"}
Inkpunk_Diffusion_V2 = False #@param {type:"boolean"}
Faetastic_inclVAE = False #@param {type:"boolean"}
Dreamshaper_33_inclVae = False #@param {type:"boolean"}
Trinart2_step95000 = False #@param {type:"boolean"}
AOM3_inclVAE = False #@param {type:"boolean"}
IlluminatiDiffusionV1_v11 = False #@param {type:"boolean"}
RevAnimated_v11_inclVAE = False #@param {type:"boolean"}
Protogen_Infinity = False #@param {type:"boolean"}
RPG_v4_inclVa = False #@param {type:"boolean"}
RealisticVisionV13_v13 = False #@param {type:"boolean"}
UberRealisticPornMerge_urpmv13 = False #@param {type:"boolean"}
Moistmix_v2 = False #@param {type:"boolean"}
EpicDiffusion_epicDiffusion11 = False #@param {type:"boolean"}
Furry_epoch4 = False #@param {type:"boolean"}
Wd_v1_3_float32 = False #@param {type:"boolean"}
#XXXXXXX = False #@param {type:"boolean"}

if F222:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Reachout/F222/resolve/main/f222.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o f222.ckpt
if Inkpunk_Diffusion_V2:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Envvi/Inkpunk-Diffusion/resolve/main/Inkpunk-Diffusion-v2.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o Inkpunk-Diffusion-v2.ckpt
if Faetastic_inclVAE:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/residentchiefnz/HordeVAEMergeModelsTest/resolve/main/Faetastic_inclVAE.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o Faetastic_inclVAE.ckpt
if Dreamshaper_33_inclVae:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Airic/Dreamshaper_33-vae/resolve/main/dreamshaper_33-inclVae.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o dreamshaper_33-inclVae.ckpt
if Trinart2_step95000:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/naclbit/trinart_stable_diffusion_v2/resolve/main/trinart2_step95000.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o trinart2_step95000.ckpt
if AOM3_inclVAE:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/residentchiefnz/HordeVAEMergeModelsTest/resolve/main/AOM3_inclVAE.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o AOM3_inclVAE.ckpt

if IlluminatiDiffusionV1_v11:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/residentchiefnz/HordeVAEMergeModelsTest/resolve/main/illuminatiDiffusionV1_v11.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o illuminatiDiffusionV1_v11.ckpt
if RevAnimated_v11_inclVAE:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/residentchiefnz/HordeVAEMergeModelsTest/resolve/main/RevAnimated_v11_inclVAE.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o RevAnimated_v11_inclVAE.ckpt
if Protogen_Infinity:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Airic/mirrors/resolve/main/Protogen_Infinity.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o Protogen_Infinity.ckpt
if RPG_v4_inclVa:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Airic/rpg/resolve/main/RPG-v4-inclVae.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o RPG-v4-inclVae.ckpt

if RealisticVisionV13_v13:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6987?type=Model&format=PickleTensor -d /content/stable-diffusion-webui/models/Stable-diffusion -o realisticVisionV13_v13.ckpt
if UberRealisticPornMerge_urpmv13:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/15640?type=Pruned%20Model&format=PickleTensor -d /content/stable-diffusion-webui/models/Stable-diffusion -o uberRealisticPornMerge_urpmv13.ckpt
if Moistmix_v2:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5955?type=Model&format=PickleTensor -d /content/stable-diffusion-webui/models/Stable-diffusion -o moistmix_v2.ckpt
if EpicDiffusion_epicDiffusion11:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5677?type=Model&format=PickleTensor -d /content/stable-diffusion-webui/models/Stable-diffusion -o epicDiffusion_epicDiffusion11.ckpt

if Furry_epoch4:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://sexy.canine.wf/file/furry-ckpt/furry_epoch4.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o furry_epoch4.ckpt
if Wd_v1_3_float32:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/hakurei/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o wd-v1-3-float32.ckpt

#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M xxxxxxx -d /content/stable-diffusion-webui/models/Stable-diffusion -o xxxxxx.ckpt

# %%
#@title 3. Download LoRAs Models
JapaneseDollLikeness_v10 = False #@param {type:"boolean"}
KoreanDollLikeness_v15 = False #@param {type:"boolean"}
TaiwanDollLikeness_v10 = False #@param {type:"boolean"}

if JapaneseDollLikeness_v10:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/nolanaatama/jdllora/resolve/main/jdllora.safetensors -d /content/stable-diffusion-webui/models/Lora -o japaneseDollLikeness_v10.safetensors
if KoreanDollLikeness_v15:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/nolanaatama/kdllora/resolve/main/kdllorav15.safetensors -d /content/stable-diffusion-webui/models/Lora -o koreanDollLikeness_v15.safetensors
if TaiwanDollLikeness_v10:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/nolanaatama/tdllora/resolve/main/tdllora.safetensors -d /content/stable-diffusion-webui/models/Lora -o taiwanDollLikeness_v10.safetensors

# %%
#@title 4. Pre-run Stable Diffusion

# !sed -i -e '''/    prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/stable-diffusion-webui/launch.py
# !sed -i -e 's/fastapi==0.94.0/fastapi==0.89.1/g' /content/stable-diffusion-webui/requirements_versions.txt

# !mkdir /content/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui/models

# %%
#@title 5. Start Stable Diffusion
# !python launch.py --listen --share --xformers --enable-insecure-extension-access --theme dark --gradio-queue # --cloudflared #--disable-nan-check
